# %%
class Universo:
    def __init__(self,nombre_universo,
                 antiguedad_universo,
                 tamanio_universo,
                 temperatura_mas_abaja_universo,
                 universo_primario):
        self.nombre_universo=nombre_universo
        self.antiguedad_universo=antiguedad_universo
        self.tamanio_universo=tamanio_universo
        self.temperatura_mas_abaja_universo=temperatura_mas_abaja_universo
        self.universo_primario=universo_primario
        self.universo=[]
    
    def __str__(self):
        parte_uno=f"{self.nombre_universo}"
        parte_dos=f"{self.antiguedad_universo}"
        parte_tres=f"{self.tamanio_universo}"
        parte_cuatro=f"{self.temperatura_mas_abaja_universo}"
        parte_cinco=f"{self.universo_primario}"
        return parte_uno+","+parte_dos+","+parte_tres+","+parte_cuatro+","+parte_cinco+"\n"

# %%
class Alien:
    def __init__(self,raza,altura,peso,edad,ostilidad,nombre_universo):
        self.raza=raza
        self.altura=altura
        self.peso=peso
        self.edad=edad
        self.ostilidad=ostilidad
        self.nombre_universo=nombre_universo
    
    def __str__(self):
        parte_uno=f"{self.raza}"
        parte_dos=f"{self.altura}"
        parte_tres=f"{self.peso}"
        parte_cuatro=f"{self.edad}"
        parte_cinco=f"{self.ostilidad}"
        parte_seis=f"{self.nombre_universo}"
        return parte_uno+","+parte_dos+","+parte_tres+","+parte_cuatro+","+parte_cinco+","+parte_seis+"\n"

# %%
#universo.txt
class Control:    
    
# Metodo de creacion del universo    
    
    def agregar_universo (self,nombre_universo,
                          antiguedad_universo,
                          tamanio_universo,
                          temperatura_mas_abaja_universo,
                          universo_primario):        
        
        univrs=Universo(str(nombre_universo),
                        int(antiguedad_universo),
                        float(tamanio_universo),
                        float(temperatura_mas_abaja_universo),
                        bool(universo_primario))        
        #datos=univrs        
        try:
            path = "./universo.txt"
            archivo_abierto= open(path, "a")
            archivo_abierto.write(str(univrs))
            #archivo_abierto1= open(path)  lectura
            #linea_uno=archivo_abierto1.readlines()
            #print(f"Archivo leido\n {linea_uno}")            
            archivo_abierto.close()       
        except Exception as Error:
            print("Error leyendo Archivo")
            
# Metodo de busqueda del universo            
            
    def buscar_universo(selff,nombre_universo):
        cont=0
        try:
            path = "./universo.txt"
            #archivo_abierto= open(path, "a")
            #archivo_abierto.write(str(univrs))
            archivo_abierto1= open(path)  #lectura
            linea_uno=archivo_abierto1.readlines()
            
            for i in range(len(linea_uno)):
                vector_temp=linea_uno[i].split(",") 
                if(vector_temp[0]==nombre_universo):                    
                    return vector_temp                    
                else:                    
                    cont = cont + 1
                    if(cont==len(linea_uno)):
                        print("universo no existente")                                                       
            archivo_abierto1.close()
        except Exception as Error:
            print("Error leyendo Archivo")

# Metodo de edicion del universo            
                    
    def editar_universo(selff,
                        nombre_universo,
                        nombre_dato):
        
        etiqueta_dato=nombre_dato.split(":")
        if ("nombre Universo"==etiqueta_dato[0]):
            indice=0
        elif ("antiguedad Universo"==etiqueta_dato[0]):
            indice=1
        elif ("tamanio Universo"==etiqueta_dato[0]):
            indice=2
        elif ("Min Temperatura Universo"==etiqueta_dato[0]):
            indice=3
        else:
            indice=4                
        #print("indices correctos")
        linea_elementos=[]
        cont=0
        try:
            path = "./universo.txt"
            archivo_abierto= open(path)  #lectura
            linea_uno=archivo_abierto.readlines()            
            for i in range(len(linea_uno)):
                vector_temp=linea_uno[i].split(",") 
                if(vector_temp[0]==nombre_universo):
                    if(indice==4):
                        vector_temp[indice]=etiqueta_dato[1]+"\n"
                    else:
                        vector_temp[indice]=etiqueta_dato[1]                
                else:                    
                    cont = cont + 1
                    if(cont==len(linea_uno)):
                        print("universo no existente")                                
                aux=(','.join(vector_temp))                
                linea_elementos.append(aux)
                        
            archivo_abierto1= open(path,'w')            
            archivo_abierto1.writelines(linea_elementos)                                                                
            archivo_abierto1.close()
        except Exception as Error:
            print("Error leyendo Archivo")                                                                

# Metodo de eliminacion del universo
                
    def eliminar_universo(self,nombre_universo):
        
        linea_elementos=[]
        cont=0
        try:
            path = "./universo.txt"
            archivo_abierto= open(path)  #lectura
            linea_uno=archivo_abierto.readlines()            
            for i in range(len(linea_uno)):
                vector_temp=linea_uno[i].split(",") 
                if(vector_temp[0]==nombre_universo):
                    vector_temp=("","","","","","")
                else:                    
                    cont = cont + 1
                    if(cont==len(linea_uno)):
                        print("universo no existente")                                
                aux=(','.join(vector_temp))
                #print(aux)
                if(aux!=",,,,,"):                    
                    linea_elementos.append(aux)
                        
            archivo_abierto1= open(path,'w')            
            archivo_abierto1.writelines(linea_elementos)                                                                
            archivo_abierto1.close()
        except Exception as Error:
            print("Error leyendo Archivo")                
        controlA=Control_alien()
        controlA.destruir_aliens_Universo(nombre_universo)
        
        
    def mostra_todo_universos(self):
        try:
            path = "./universo.txt"                        
            archivo_abierto1= open(path)  #lectura
            linea_uno=archivo_abierto1.readlines()
            return linea_uno
            archivo_abierto1.close()
        except Exception as Error:
            print("Error leyendo Archivo")

# %%
#aliens.txt

class Control_alien:
    
# Metodo de creacion de aliens
    
    def agregar_alien (self,raza,altura,peso,edad,ostilidad,nombre_universo):                                                    
                          
        alien=Alien(str(raza),
                    float(altura),
                    float(peso),
                    int(edad),
                    bool(ostilidad),
                    str(nombre_universo))
                
        #datos=alien        
        try:
            path = "./aliens.txt"
            archivo_abierto= open(path, "a")
            archivo_abierto.write(str(alien))
            #archivo_abierto1= open(path)  lectura
            #linea_uno=archivo_abierto1.readlines()
            #print(f"Archivo leido\n {linea_uno}")            
            archivo_abierto.close()       
        except Exception as Error:
            print("Error leyendo Archivo")
            
# Metodo de busqueda del alien            
            
    def buscar_alien(selff,raza):
        cont=0
        try:
            path = "./aliens.txt"
            #archivo_abierto= open(path, "a")
            #archivo_abierto.write(str(univrs))
            archivo_abierto1= open(path)  #lectura
            linea_uno=archivo_abierto1.readlines()
            
            for i in range(len(linea_uno)):
                vector_temp=linea_uno[i].split(",") 
                if(vector_temp[0]==raza):                    
                    return vector_temp                    
                else:                    
                    cont = cont + 1
                    if(cont==len(linea_uno)):
                        print("alien no existente")                                                       
            archivo_abierto1.close()
        except Exception as Error:
            print("Error leyendo Archivo")

# Metodo de edicion del alien            
                    
    def editar_alien(selff,
                        raza,
                        nombre_dato):
        
        etiqueta_dato=nombre_dato.split(":")
        if ("raza alien"==etiqueta_dato[0]):
            indice=0
        elif ("altura Alien"==etiqueta_dato[0]):
            indice=1
        elif ("peso Alien"==etiqueta_dato[0]):
            indice=2
        elif ("edad Alien"==etiqueta_dato[0]):
            indice=3
        elif ("Ostilidad"==etiqueta_dato[0]):
            indice=4
        else:
            indice=5
        #print("indices correctos")
        linea_elementos=[]
        cont=0
        try:
            path = "./aliens.txt"
            archivo_abierto= open(path)  #lectura
            linea_uno=archivo_abierto.readlines()            
            for i in range(len(linea_uno)):
                vector_temp=linea_uno[i].split(",") 
                if(vector_temp[0]==raza):
                    if(indice==5):
                        vector_temp[indice]=etiqueta_dato[1]+"\n"
                    else:
                        vector_temp[indice]=etiqueta_dato[1]
                else:                    
                    cont = cont + 1
                    if(cont==len(linea_uno)):
                        print("aliens.txt no existente")                                
                aux=(','.join(vector_temp))                
                linea_elementos.append(aux)
                        
            archivo_abierto1= open(path,'w')            
            archivo_abierto1.writelines(linea_elementos)                                                                
            archivo_abierto1.close()
        except Exception as Error:
            print("Error leyendo Archivo")                                                                

# Metodo de eliminacion del alien
                
    def eliminar_alien(self,raza):
        
        linea_elementos=[]
        cont=0
        try:
            path = "./aliens.txt"
            archivo_abierto = open(path)  #lectura
            linea_uno=archivo_abierto.readlines()            
            for i in range(len(linea_uno)):
                vector_temp=linea_uno[i].split(",") 
                if(vector_temp[0]==raza):
                    vector_temp=("","","","","","")
                else:                    
                    cont = cont + 1
                    if(cont==len(linea_uno)):
                        print("alien no existente")                                
                aux=(','.join(vector_temp))
                #print(aux)
                if(aux!=",,,,,"):                    
                    linea_elementos.append(aux)
                        
            archivo_abierto1= open(path,'w')            
            archivo_abierto1.writelines(linea_elementos)                                                                
            archivo_abierto1.close()
        except Exception as Error:
            print("Error leyendo Archivo")        
        

#  Metodo de eliminacion del alien (Si borranUniverso)
        
              
    def destruir_aliens_Universo(self,nombre_universo):
        
        linea_elementos=[]
        cont=0
        try:
            path = "./aliens.txt"
            archivo_abierto = open(path)  #lectura
            linea_uno=archivo_abierto.readlines()            
            for i in range(len(linea_uno)):
                vector_temp=linea_uno[i].split(",") 
                if(vector_temp[5]==nombre_universo+"\n"):
                    vector_temp=("","","","","","")
                else:                    
                    cont = cont + 1
                    if(cont==len(linea_uno)):
                        print("alien no existente")                                
                aux=(','.join(vector_temp))
                #print(aux)
                if(aux!=",,,,,"):                    
                    linea_elementos.append(aux)
                        
            archivo_abierto1= open(path,'w')            
            archivo_abierto1.writelines(linea_elementos)                                                                
            archivo_abierto1.close()
        except Exception as Error:
            print("Error leyendo Archivo")   
            
            
            
# Mostrar todos los alienigenas 


    def mostra_todo_aliens(self):
        try:
            path = "./aliens.txt"
            archivo_abierto1= open(path)  #lectura
            linea_uno=archivo_abierto1.readlines()
            return linea_uno
            archivo_abierto1.close()
        except Exception as Error:
            print("Error leyendo Archivo")

# %%
import sys

# %%
class Menu_universo:
    
    def __init__(self):
        #self.cuaderno=Cauaderno()
        self.elecciones={
            "1":self.agregar_un_universo,
            "2":self.buscar_universo, 
            "3":self.modificar_universo,
            "4":self.eliminar_universos,
            "5":self.mostar_universos,
            "6": self.salir
        }
    
    def mostrar_menu(self) :
        print("""        
        Menu Universo

1 Agregar un Universo
2 Buscar un universo especifico
3 Modificar un Universo
4 Eliminar un universo
5 Mostra todos los universos existentes
6 salir                
""")
    
    def run(self):
                
        while True:
            self.mostrar_menu()
            eleccion=input("Escribe una opcion: ")
            accion=self.elecciones.get(eleccion)
            if accion:
                accion()
            else:
                print("{0} no es una eleccion valida".format(eleccion))
        
    def agregar_un_universo(self):
        print("CREACION UNIVERSO")        
        print("Ingresa la siguente informacion")        
        nombre_universo=input("Nombre universo: ")
        antiguedad_universo=input("Antiguedad universo: ")
        tamanio_universo=input("Tamanio universo: ")
        temperatura_mas_abaja_universo=input("Min. temperatura universo: ")
        universo_primario=input("El univrso es primario: ")
        control=Control()
        control.agregar_universo(nombre_universo,
                                 antiguedad_universo,
                                 tamanio_universo,
                                 temperatura_mas_abaja_universo,
                                 universo_primario)
    
    
    def buscar_universo(self):
        print("BUSQUEDA UNIVERSO")
        nom_universo=input("Ingresa nombre del universo a buscar: ")        
        control=Control()
        vect=control.buscar_universo(nom_universo)
        print(vect)
    
    def modificar_universo(self):
        
        print("MODIFICACION UNIVERSO")        
        print("Formato de ingreso")
        print("nombre Universo:universoA-32")
        print("antiguedad Universo:55000")
        print("tamanio Universo:234332.433")
        print("Min Temperatura Universo:273.2")
        print("Universo primario:True")
        control=Control()
        dato_nom_univ=input("Ingresa nombre del universo a modificar: ")
        dato_modificacion=input("Ingresa la modificacion: ")        
        control.editar_universo(dato_nom_univ,dato_modificacion)
        
    
    def eliminar_universos(self):
        print("ELIMINAR UNIVERSO")        
        print("usa el nombre del universo a destruir *recuerda que los aliens del universo tambien moriran*")
        nom_universo_borrado=input("Ingresa nombre del universo a eliminar: ")
        control=Control()
        control.eliminar_universo(nom_universo_borrado)        
    

    def mostar_universos(self):
        control=Control()
        tem=control.mostra_todo_universos()
        print(tem)
        
    def salir(self):
        print("Gracias por ingresar!")
        sys.exit(0)

# %%
m=Menu_universo()
m.run()
# Out:
#
#         Menu Universo
#
# 1 Agregar un Universo
# 2 Buscar un universo especifico
# 3 Modificar un Universo
# 4 Eliminar un universo
# 5 Mostra todos los universos existentes
# 6 salir
#
# Escribe una opcion: 4
# ELIMINAR UNIVERSO
# usa el nombre del universo a destruir *recuerda que los aliens del universo tambien moriran*
# Ingresa nombre del universo a eliminar: universo-M-82
# universo no existente
#
#         Menu Universo
#
# 1 Agregar un Universo
# 2 Buscar un universo especifico
# 3 Modificar un Universo
# 4 Eliminar un universo
# 5 Mostra todos los universos existentes
# 6 salir
#
# Escribe una opcion: 5
# ['universo-A-554,4444444,234332.433,273.2,True\n', 'universo-ZM-32,5000,288332.4,211.21,False\n', 'universo-M-182,8349,56332.0,22.9,False\n', 'universo-G-29,9049,70332.24,12.2,True\n', 'universo-N-56,4549,23332.19,52.5,False\n', 'universo-P-37,7345,18032.3,82.8,True\n', 'universo-MN-2324,4635345,34.54,234.545,True\n']
#
#         Menu Universo
#
# 1 Agregar un Universo
# 2 Buscar un universo especifico
# 3 Modificar un Universo
# 4 Eliminar un universo
# 5 Mostra todos los universos existentes
# 6 salir
#
# Escribe una opcion: 6
# Gracias por ingresar!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
class Menu_aliens:
    
    def __init__(self):
        #self.cuaderno=Cauaderno()
        self.elecciones={
            "1":self.agregar_un_alienigena,
            "2":self.buscar_alienigena, 
            "3":self.modificar_alienigena,
            "4":self.eliminar_alienigena,
            "5":self.mostar_alienigenas,
            "6": self.salir
        }
    
    def mostrar_menu(self) :
        print("""        
        Menu Alienigena

1 Agregar un Aliens
2 Buscar un alien especifico
3 Modificar un alien
4 Eliminar un alien
5 Mostra todos los aliens existentes
6 salir                
""")
    
    def run(self):
                
        while True:
            self.mostrar_menu()
            eleccion=input("Escribe una opcion: ")
            accion=self.elecciones.get(eleccion)
            if accion:
                accion()
            else:
                print("{0} no es una eleccion valida".format(eleccion))
        
    def agregar_un_alienigena(self):
        print("CREACION ALIENIGENA")        
        print("Ingresa la siguente informacion")        
        raza=input("raza del alienigena: ")
        altura=input("altura alienigena: ")
        peso=input("peso alienigena: ")
        edad=input("edad alienigena: ")
        ostilidad=input("ostilidad alienigena: ")
        nombre_universo=input("universo del alienigena: ")
        
        control=Control_alien()
        control.agregar_alien(raza,
                              altura,
                              peso,
                              edad,
                              ostilidad,
                              nombre_universo)
        
    
    def buscar_alienigena(self):
        print("BUSQUEDA ALIENIGENA")
        nom_alien=input("Ingresa nombre del alien a buscar: ")        
        control=Control_alien()
        vect=control.buscar_alien(nom_alien)
        print(vect)
        
    
    def modificar_alienigena(self):
        
        print("MODIFICACION ALIENIGENA")        
        print("Formato de ingreso\n")
        print("raza alien:omicroniano")
        print("altura Alien:2.23")
        print("peso Alien:50.4")
        print("edad Alien:25")
        print("Ostilidad:False")
        print("Universo:universoA-32")
        
        control=Control_alien()
        dato_nom_alien=input("Ingresa la raza del alien a modificar: ")
        dato_modificacion=input("Ingresa la modificacion: ")        
        control.editar_alien(dato_nom_alien,dato_modificacion)
        
    
    def eliminar_alienigena(self):
        print("ELIMINAR ALIENIGENA")        
        print("usa el nombre de la raza a destruir")
        nom_alien_borrado=input("Ingresa nombre de la raza alienigena a eliminar: ")
        control=Control_alien()
        control.eliminar_alien(nom_alien_borrado)
    

    def mostar_alienigenas(self):
        control=Control_alien()
        tem=control.mostra_todo_aliens()
        print(tem)
        
    def salir(self):
        print("Gracias por ingresar!")
        sys.exit(0)

# %%
m=Menu_aliens()
m.run()
# Out:
#
#         Menu Alienigena
#
# 1 Agregar un Aliens
# 2 Buscar un alien especifico
# 3 Modificar un alien
# 4 Eliminar un alien
# 5 Mostra todos los aliens existentes
# 6 salir
#
# Escribe una opcion: 5
# ['Omicroniano,2.23,50.4,25,False,universo-A-554\n', 'Draconiano,2.5,60.5,20,True,universo-M-82\n', 'Kitsune,1.9,30.7,21,False,universo-B-32\n', 'Lisovik,2.45,44.2,22,True,universo-M-82\n', 'Leshi,1.45,44.2,22,False,universo-M-82\n', 'Licano,3.66,44.2,22,True,universo-M-82\n', 'Selkie,1.59,44.2,22,False,universo-M-82\n', 'Coatl,2.7,44.2,22,True,universo-M-82\n', 'Cerberus,3.23,44.2,22,True,universo-M-82\n', 'Leviatanus,3.15,44.2,22,True,universo-M-82\n', 'Enits,2.8,44.2,22,False,universo-M-82\n', 'Hidra,1.75,44.2,22,False,universo-M-82\n', 'Yotshum,1.68,44.2,22,False,universo-M-82\n', 'Repts,2.35,44.2,22,True,universo-M-82\n', 'Yamats,2.92,44.2,22,False,universo-M-82\n']
#
#         Menu Alienigena
#
# 1 Agregar un Aliens
# 2 Buscar un alien especifico
# 3 Modificar un alien
# 4 Eliminar un alien
# 5 Mostra todos los aliens existentes
# 6 salir
#
# Escribe una opcion: 1
# CREACION ALIENIGENA
# Ingresa la siguente informacion
# raza del alienigena: ashbshdf
# altura alienigena: 2.345
# peso alienigena: 34.456
# edad alienigena: 25
# ostilidad alienigena: True
# universo del alienigena: universo-M-82
#
#         Menu Alienigena
#
# 1 Agregar un Aliens
# 2 Buscar un alien especifico
# 3 Modificar un alien
# 4 Eliminar un alien
# 5 Mostra todos los aliens existentes
# 6 salir
#
# Escribe una opcion: 5
# ['Omicroniano,2.23,50.4,25,False,universo-A-554\n', 'Draconiano,2.5,60.5,20,True,universo-M-82\n', 'Kitsune,1.9,30.7,21,False,universo-B-32\n', 'Lisovik,2.45,44.2,22,True,universo-M-82\n', 'Leshi,1.45,44.2,22,False,universo-M-82\n', 'Licano,3.66,44.2,22,True,universo-M-82\n', 'Selkie,1.59,44.2,22,False,universo-M-82\n', 'Coatl,2.7,44.2,22,True,universo-M-82\n', 'Cerberus,3.23,44.2,22,True,universo-M-82\n', 'Leviatanus,3.15,44.2,22,True,universo-M-82\n', 'Enits,2.8,44.2,22,False,universo-M-82\n', 'Hidra,1.75,44.2,22,False,universo-M-82\n', 'Yotshum,1.68,44.2,22,False,universo-M-82\n', 'Repts,2.35,44.2,22,True,universo-M-82\n', 'Yamats,2.92,44.2,22,False,universo-M-82\n', 'ashbshdf,2.345,34.456,25,True,universo-M-82\n']
#
#         Menu Alienigena
#
# 1 Agregar un Aliens
# 2 Buscar un alien especifico
# 3 Modificar un alien
# 4 Eliminar un alien
# 5 Mostra todos los aliens existentes
# 6 salir
#
# Escribe una opcion: 2
# BUSQUEDA ALIENIGENA
# Ingresa nombre del alien a buscar: ashbshdf
# ['ashbshdf', '2.345', '34.456', '25', 'True', 'universo-M-82\n']
#
#         Menu Alienigena
#
# 1 Agregar un Aliens
# 2 Buscar un alien especifico
# 3 Modificar un alien
# 4 Eliminar un alien
# 5 Mostra todos los aliens existentes
# 6 salir
#
# Escribe una opcion: 3
# MODIFICACION ALIENIGENA
# Formato de ingreso
#
# raza alien:omicroniano
# altura Alien:2.23
# peso Alien:50.4
# edad Alien:25
# Ostilidad:False
# Universo:universoA-32
# Ingresa la raza del alien a modificar: ashbshdf
# Ingresa la modificacion: edad Alien:5555
#
#         Menu Alienigena
#
# 1 Agregar un Aliens
# 2 Buscar un alien especifico
# 3 Modificar un alien
# 4 Eliminar un alien
# 5 Mostra todos los aliens existentes
# 6 salir
#
# Escribe una opcion: 5
# ['Omicroniano,2.23,50.4,25,False,universo-A-554\n', 'Draconiano,2.5,60.5,20,True,universo-M-82\n', 'Kitsune,1.9,30.7,21,False,universo-B-32\n', 'Lisovik,2.45,44.2,22,True,universo-M-82\n', 'Leshi,1.45,44.2,22,False,universo-M-82\n', 'Licano,3.66,44.2,22,True,universo-M-82\n', 'Selkie,1.59,44.2,22,False,universo-M-82\n', 'Coatl,2.7,44.2,22,True,universo-M-82\n', 'Cerberus,3.23,44.2,22,True,universo-M-82\n', 'Leviatanus,3.15,44.2,22,True,universo-M-82\n', 'Enits,2.8,44.2,22,False,universo-M-82\n', 'Hidra,1.75,44.2,22,False,universo-M-82\n', 'Yotshum,1.68,44.2,22,False,universo-M-82\n', 'Repts,2.35,44.2,22,True,universo-M-82\n', 'Yamats,2.92,44.2,22,False,universo-M-82\n', 'ashbshdf,2.345,34.456,5555,True,universo-M-82\n']
#
#         Menu Alienigena
#
# 1 Agregar un Aliens
# 2 Buscar un alien especifico
# 3 Modificar un alien
# 4 Eliminar un alien
# 5 Mostra todos los aliens existentes
# 6 salir
#
# Escribe una opcion: 4
# ELIMINAR ALIENIGENA
# usa el nombre de la raza a destruir
# Ingresa nombre de la raza alienigena a eliminar: ashbshdf
#
#         Menu Alienigena
#
# 1 Agregar un Aliens
# 2 Buscar un alien especifico
# 3 Modificar un alien
# 4 Eliminar un alien
# 5 Mostra todos los aliens existentes
# 6 salir
#
# Escribe una opcion: 5
# ['Omicroniano,2.23,50.4,25,False,universo-A-554\n', 'Draconiano,2.5,60.5,20,True,universo-M-82\n', 'Kitsune,1.9,30.7,21,False,universo-B-32\n', 'Lisovik,2.45,44.2,22,True,universo-M-82\n', 'Leshi,1.45,44.2,22,False,universo-M-82\n', 'Licano,3.66,44.2,22,True,universo-M-82\n', 'Selkie,1.59,44.2,22,False,universo-M-82\n', 'Coatl,2.7,44.2,22,True,universo-M-82\n', 'Cerberus,3.23,44.2,22,True,universo-M-82\n', 'Leviatanus,3.15,44.2,22,True,universo-M-82\n', 'Enits,2.8,44.2,22,False,universo-M-82\n', 'Hidra,1.75,44.2,22,False,universo-M-82\n', 'Yotshum,1.68,44.2,22,False,universo-M-82\n', 'Repts,2.35,44.2,22,True,universo-M-82\n', 'Yamats,2.92,44.2,22,False,universo-M-82\n']
#
#         Menu Alienigena
#
# 1 Agregar un Aliens
# 2 Buscar un alien especifico
# 3 Modificar un alien
# 4 Eliminar un alien
# 5 Mostra todos los aliens existentes
# 6 salir
#
# Escribe una opcion: 6
# Gracias por ingresar!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
#control1=Control()
#control1.agregar_universo("universo-A-554",76000,234332.433,273.2,True)
#control1.agregar_universo("universo-ZM-32",5000,288332.4,211.21,False)
#control1.agregar_universo("universo-M-182",8349,56332.00,22.9,False)
#control1.agregar_universo("universo-G-29",9049,70332.240,12.20,True)
#control1.agregar_universo("universo-N-56",4549,23332.190,52.5,False)
#control1.agregar_universo("universo-P-37",7345,18032.30,82.8,True)

# %%
#control2=Control_alien()
#control2.agregar_alien("Omicroniano",2.23,50.4,25,False,"universo-A-554")
#control2.agregar_alien("Draconiano",2.50,60.5,20,True,"universo-M-82")
#control2.agregar_alien("Kitsune",1.90,30.7,21,False,"universo-B-32")
#control2.agregar_alien("Lisovik",2.45,44.2,22,True,"universo-M-82")
#control2.agregar_alien("Leshi",1.45,44.2,22,False,"universo-M-82")
#control2.agregar_alien("Licano",3.66,44.2,22,True,"universo-M-82")
#control2.agregar_alien("Selkie",1.59,44.2,22,False,"universo-M-82")
#control2.agregar_alien("Coatl",2.70,44.2,22,True,"universo-M-82")
#control2.agregar_alien("Cerberus",3.23,44.2,22,True,"universo-M-82")
#control2.agregar_alien("Leviatanus",3.15,44.2,22,True,"universo-M-82")
#control2.agregar_alien("Enits",2.80,44.2,22,False,"universo-M-82")
#control2.agregar_alien("Hidra",1.75,44.2,22,False,"universo-M-82")
#control2.agregar_alien("Yotshum",1.68,44.2,22,False,"universo-M-82")
#control2.agregar_alien("Repts",2.35,44.2,22,True,"universo-M-82")
#control2.agregar_alien("Yamats",2.92,44.2,22,False,"universo-M-82")
